# %% [markdown]
# # 02 - Stratégies de Vectorisation
#
# **Objectif**: Trouver la meilleure méthode de représentation des features textuelles.
#
# **Méthodologie**:
# - **Modèle fixé**: Logistic Regression (contrôle de variable)
# - **Preprocessing**: `final_text_cleaner()` (from Notebook 01)
# - **Variables testées**: Vectorizer, Features, Strategy, Hyperparamètres
#
# **Output**: Configuration optimale → `configs/best_vectorization_config.json`

# %% [markdown]
# ## 1. Setup & Configuration

# %%
import sys
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

sys.path.insert(0, '../src')

# Imports Phase 2
from rakuten_text import (
    # Preprocessing (Phase 1)
    final_text_cleaner,
    
    # Features
    extract_text_features,
    get_feature_names,
    
    # Vectorization
    save_vectorization_config,
    
    # Experiments
    run_single_experiment,
    run_strategy_comparison,
    run_hyperparameter_grid,
    run_title_weighting_experiment,
    analyze_experiment_results,
    generate_vectorization_report,
)

from sklearn.model_selection import train_test_split

print("✓ Imports réussis")
# Out:
# ✓ Imports réussis

# %% [markdown]
# ## 2. Chargement et Preprocessing

# %%
# Charger données
print("Chargement...")
X_train_full = pd.read_csv('../data/X_train_update.csv', index_col=0)
y_train_full = pd.read_csv('../data/Y_train_CVw08PX.csv', index_col=0)['prdtypecode']

print(f"✓ {X_train_full.shape[0]} échantillons, {y_train_full.nunique()} classes")

# Appliquer preprocessing optimal (from Notebook 01)
print("\nPreprocessing avec final_text_cleaner()...")
X_train_full['title_clean'] = X_train_full['designation'].fillna('').apply(final_text_cleaner)
X_train_full['desc_clean'] = X_train_full['description'].fillna('').apply(final_text_cleaner)

print("✓ Textes nettoyés")
# Out:
# Chargement...
# ✓ 84916 échantillons, 27 classes
#
# Preprocessing avec final_text_cleaner()...
# ✓ Textes nettoyés

# %% [markdown]
# ## 3. Feature Engineering

# %%
# Extraire features manuelles
print("Extraction des features manuelles...")
features = extract_text_features(
    X_train_full,
    text_columns=['designation', 'description'],
    verbose=True
)

# Ajouter au DataFrame
for col in features.columns:
    X_train_full[col] = features[col]

feature_columns = list(features.columns)
print(f"\n✓ {len(feature_columns)} features extraites")
print(f"Features: {feature_columns[:3]}...")
# Out:
# Extraction des features manuelles...
# Extraction des features manuelles...
#   Colonnes à analyser: ['designation', 'description']
#   → Traitement de 'designation'...
#   → Traitement de 'description'...
# ✓ Extraction terminée: 12 features créées
#   Noms: ['designation_len_char', 'designation_len_words', 'designation_num_digits']...
#
# ✓ 12 features extraites
# Features: ['designation_len_char', 'designation_len_words', 'designation_num_digits']...

# %% [markdown]
# ## 4. Train/Val Split

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full,
    y_train_full,
    test_size=0.15,
    stratify=y_train_full,
    random_state=42
)

print(f"Train: {len(X_train)} | Val: {len(X_val)}")
# Out:
# Train: 72178 | Val: 12738

# %% [markdown]
# ## 5. Expérience 1: Comparaison Vectorization Methods
#
# Test: Count vs TF-IDF (sans features manuelles)

# %%
# baseline_raw_f1 from Notebook 01
baseline_f1 = 0.7925

print("Test 1: Count vs TF-IDF (Split, sans features)\n")

results_vec = []

# TF-IDF Split
result_tfidf = run_single_experiment(
    X_train, X_val, y_train, y_val,
    vectorizer_type='tfidf',
    strategy='split',
    text_columns=['title_clean', 'desc_clean'],
    feature_columns=None,
    max_features=10000,
    ngram_range=(1, 2),
    model_name='logreg',
    verbose=True
)

results_vec.append({
    'method': 'TF-IDF Split',
    'f1_score': result_tfidf['f1_score'],
    'accuracy': result_tfidf['accuracy']
})

# Count Split
result_count = run_single_experiment(
    X_train, X_val, y_train, y_val,
    vectorizer_type='count',
    strategy='split',
    text_columns=['title_clean', 'desc_clean'],
    feature_columns=None,
    max_features=10000,
    ngram_range=(1, 2),
    model_name='logreg',
    verbose=True
)

results_vec.append({
    'method': 'Count Split',
    'f1_score': result_count['f1_score'],
    'accuracy': result_count['accuracy']
})

df_vec = pd.DataFrame(results_vec)
print("\n" + "="*60)
print("RÉSULTATS:")
print(df_vec.to_string(index=False))
print("="*60)
# Out:
# Test 1: Count vs TF-IDF (Split, sans features)
#
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 10000
#   N-gram range: (1, 2)
#   Features manuelles: Non
# ================================================================================
#
# Entraînement du pipeline...
# ✓ Entraînement terminé en 20.61s
#
# ================================================================================
# RÉSULTATS DE L'ÉVALUATION
# ================================================================================
# F1-Score (weighted): 0.8250
# Accuracy:            0.8235
# Temps prédiction:    1.19s
#
# Rapport de classification:
# --------------------------------------------------------------------------------
#                         precision    recall  f1-score   support
#
#      Livres techniques       0.41      0.61      0.49       467
#           Rétro Gaming       0.76      0.67      0.71       376
#         Accessoires JV       0.86      0.85      0.86       252
#               Consoles       0.97      0.74      0.84       125
#               Figurine       0.76      0.79      0.78       401
# Cartes à collectionner       0.91      0.92      0.91       593
#           Jeux de rôle       0.79      0.48      0.59       115
#     Jouets & Figurines       0.74      0.74      0.74       731
#         Jeux éducatifs       0.72      0.50      0.59       311
#     Modélisme & Drones       0.97      0.95      0.96       757
#            Bébé & Jeux       1.00      0.94      0.97       121
#        Sport & Loisirs       0.87      0.75      0.81       374
#    Bébé & Puériculture       0.81      0.77      0.79       486
#      Équipement maison       0.86      0.83      0.84       761
#               Textiles       0.90      0.92      0.91       646
#           Alimentation       0.93      0.82      0.87       120
#       Déco & Éclairage       0.81      0.84      0.83       749
#                Animaux       0.94      0.78      0.85       124
#   Journaux & magazines       0.70      0.83      0.76       714
# Séries & encyclopédies       0.75      0.76      0.75       716
#             Jeux Vidéo       0.80      0.80      0.80       213
#     Fournitures bureau       0.90      0.93      0.91       748
#       Jardinage & déco       0.80      0.73      0.76       388
#                Piscine       0.96      0.98      0.97      1531
#     Jardin & Bricolage       0.83      0.80      0.81       374
#   Romans & littérature       0.83      0.68      0.75       414
#                Jeux PC       1.00      0.99      1.00       131
#
#               accuracy                           0.82     12738
#              macro avg       0.84      0.79      0.81     12738
#           weighted avg       0.83      0.82      0.83     12738
#
#
# ================================================================================
# Expérience: COUNT + LOGREG
#   Strategy: split
#   Max features: 10000
#   N-gram range: (1, 2)
#   Features manuelles: Non
# ================================================================================
#
# Entraînement du pipeline...
# ✓ Entraînement terminé en 29.00s
#
# ================================================================================
# RÉSULTATS DE L'ÉVALUATION
# ================================================================================
# F1-Score (weighted): 0.8187
# Accuracy:            0.8160
# Temps prédiction:    1.17s
#
# Rapport de classification:
# --------------------------------------------------------------------------------
#                         precision    recall  f1-score   support
#
#      Livres techniques       0.41      0.69      0.51       467
#           Rétro Gaming       0.73      0.68      0.70       376
#         Accessoires JV       0.86      0.81      0.84       252
#               Consoles       0.94      0.83      0.88       125
#               Figurine       0.78      0.80      0.79       401
# Cartes à collectionner       0.94      0.92      0.93       593
#           Jeux de rôle       0.80      0.57      0.67       115
#     Jouets & Figurines       0.72      0.69      0.71       731
#         Jeux éducatifs       0.62      0.53      0.57       311
#     Modélisme & Drones       0.96      0.94      0.95       757
#            Bébé & Jeux       0.98      0.95      0.97       121
#        Sport & Loisirs       0.84      0.73      0.78       374
#    Bébé & Puériculture       0.79      0.78      0.78       486
#      Équipement maison       0.85      0.82      0.83       761
#               Textiles       0.91      0.91      0.91       646
#           Alimentation       0.93      0.85      0.89       120
#       Déco & Éclairage       0.80      0.78      0.79       749
#                Animaux       0.90      0.76      0.82       124
#   Journaux & magazines       0.76      0.80      0.78       714
# Séries & encyclopédies       0.74      0.75      0.74       716
#             Jeux Vidéo       0.80      0.81      0.81       213
#     Fournitures bureau       0.91      0.93      0.92       748
#       Jardinage & déco       0.75      0.72      0.74       388
#                Piscine       0.96      0.97      0.96      1531
#     Jardin & Bricolage       0.79      0.79      0.79       374
#   Romans & littérature       0.79      0.68      0.73       414
#                Jeux PC       1.00      0.99      1.00       131
#
#               accuracy                           0.82     12738
#              macro avg       0.82      0.80      0.81     12738
#           weighted avg       0.83      0.82      0.82     12738
#
#
# ============================================================
# RÉSULTATS:
#       method  f1_score  accuracy
# TF-IDF Split  0.825009  0.823520
#  Count Split  0.818727  0.815984
# ============================================================

# %% [markdown]
# ## 6. Expérience 2: Split vs Merged Strategy
#
# Comparaison détaillée des deux stratégies

# %%
print("Test 2: Split vs Merged (TF-IDF)\n")

# Créer colonne merged pour test
X_train['text_merged'] = X_train['title_clean'] + ' ' + X_train['desc_clean']
X_val['text_merged'] = X_val['title_clean'] + ' ' + X_val['desc_clean']

# TF-IDF Merged
result_merged = run_single_experiment(
    X_train, X_val, y_train, y_val,
    vectorizer_type='tfidf',
    strategy='merged',
    text_columns=['text_merged'],
    feature_columns=None,
    max_features=10000,
    ngram_range=(1, 2),
    model_name='logreg',
    verbose=True
)

print("\n" + "="*60)
print("COMPARAISON Split vs Merged:")
print(f"  Split:  F1 = {result_tfidf['f1_score']:.4f}")
print(f"  Merged: F1 = {result_merged['f1_score']:.4f}")
improvement = (result_tfidf['f1_score'] - result_merged['f1_score']) / result_merged['f1_score'] * 100
print(f"  → Split est {improvement:+.2f}% meilleur")
print("="*60)
# Out:
# Test 2: Split vs Merged (TF-IDF)
#
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: merged
#   Max features: 10000
#   N-gram range: (1, 2)
#   Features manuelles: Non
# ================================================================================
#
# Entraînement du pipeline...
# ✓ Entraînement terminé en 21.58s
#
# ================================================================================
# RÉSULTATS DE L'ÉVALUATION
# ================================================================================
# F1-Score (weighted): 0.7950
# Accuracy:            0.7944
# Temps prédiction:    1.24s
#
# Rapport de classification:
# --------------------------------------------------------------------------------
#                         precision    recall  f1-score   support
#
#      Livres techniques       0.38      0.60      0.46       467
#           Rétro Gaming       0.75      0.63      0.68       376
#         Accessoires JV       0.80      0.82      0.81       252
#               Consoles       0.93      0.76      0.84       125
#               Figurine       0.75      0.76      0.75       401
# Cartes à collectionner       0.88      0.89      0.89       593
#           Jeux de rôle       0.80      0.44      0.57       115
#     Jouets & Figurines       0.69      0.62      0.65       731
#         Jeux éducatifs       0.60      0.43      0.50       311
#     Modélisme & Drones       0.88      0.93      0.90       757
#            Bébé & Jeux       0.98      0.91      0.94       121
#        Sport & Loisirs       0.82      0.70      0.76       374
#    Bébé & Puériculture       0.77      0.73      0.75       486
#      Équipement maison       0.82      0.81      0.82       761
#               Textiles       0.89      0.92      0.91       646
#           Alimentation       0.89      0.80      0.84       120
#       Déco & Éclairage       0.78      0.81      0.80       749
#                Animaux       0.93      0.73      0.81       124
#   Journaux & magazines       0.70      0.80      0.74       714
# Séries & encyclopédies       0.74      0.70      0.72       716
#             Jeux Vidéo       0.78      0.73      0.75       213
#     Fournitures bureau       0.88      0.93      0.90       748
#       Jardinage & déco       0.78      0.72      0.75       388
#                Piscine       0.95      0.98      0.97      1531
#     Jardin & Bricolage       0.81      0.76      0.79       374
#   Romans & littérature       0.76      0.67      0.71       414
#                Jeux PC       1.00      0.97      0.98       131
#
#               accuracy                           0.79     12738
#              macro avg       0.80      0.76      0.78     12738
#           weighted avg       0.80      0.79      0.80     12738
#
#
# ============================================================
# COMPARAISON Split vs Merged:
#   Split:  F1 = 0.8250
#   Merged: F1 = 0.7950
#   → Split est +3.77% meilleur
# ============================================================

# %% [markdown]
# ## 6b. Expérience 2b: Pondération du Titre
#
# **Question**: Le titre contient-il plus d'information discriminante que la description?
#
# **Test**: Pondérer les features du titre par un facteur multiplicatif (1x à 3x)

# %%
print("Test 2b: Pondération du Titre (TF-IDF Split)\n")

# Tester différents poids pour le titre: 1x, 1.5x, 2x, 2.5x, 3x
results_weighting = run_title_weighting_experiment(
    X_train, X_val, y_train, y_val,
    text_columns=['title_clean', 'desc_clean'],
    feature_columns=None,  # Sans features manuelles pour isoler l'effet
    title_weights=[1.0, 1.5, 2.0, 2.5, 3.0],
    vectorizer_type='tfidf',
    max_features=10000,
    ngram_range=(1, 2),
    model_name='logreg',
    verbose=True
)

print("\n✓ Test de pondération terminé")
# Out:
# Test 2b: Pondération du Titre (TF-IDF Split)
#
#
# ================================================================================
# TEST DE PONDÉRATION DU TITRE
# ================================================================================
# Poids à tester: [1.0, 1.5, 2.0, 2.5, 3.0]
# Vectorizer: TFIDF
# Max features: 10000 (par colonne)
# N-gram range: (1, 2)
# Modèle: LOGREG
# ================================================================================
#
#
# [1/5] Test avec title_weight = 1.0x
# --------------------------------------------------------------------------------
#   → F1-Score: 0.8250
#   → Accuracy: 0.8235
#   → Train time: 20.49s
#
# [2/5] Test avec title_weight = 1.5x
# --------------------------------------------------------------------------------
#   → F1-Score: 0.8310
#   → Accuracy: 0.8300
#   → Train time: 20.52s
#
# [3/5] Test avec title_weight = 2.0x
# --------------------------------------------------------------------------------
#   → F1-Score: 0.8289
#   → Accuracy: 0.8279
#   → Train time: 20.83s
#
# [4/5] Test avec title_weight = 2.5x
# --------------------------------------------------------------------------------
#   → F1-Score: 0.8272
#   → Accuracy: 0.8262
#   → Train time: 18.56s
#
# [5/5] Test avec title_weight = 3.0x
# --------------------------------------------------------------------------------
#   → F1-Score: 0.8232
#   → Accuracy: 0.8221
#   → Train time: 19.36s
#
# ================================================================================
# RÉSULTATS DE LA PONDÉRATION DU TITRE
# ================================================================================
#
#  title_weight  f1_score  accuracy  train_time
#           1.5  0.830966  0.829958   20.518166
#           2.0  0.828940  0.827916   20.828733
#           2.5  0.827166  0.826189   18.563941
#           1.0  0.825009  0.823520   20.491603
#           3.0  0.823182  0.822107   19.358420
#
# ================================================================================
# ANALYSE
# ================================================================================
# Baseline (weight=1.0): F1 = 0.8250
# Meilleur (weight=1.5): F1 = 0.8310
# Amélioration: +0.60%
# ================================================================================
#
#
# ✓ Test de pondération terminé

# %% [markdown]
# ## 7. Expérience 3: Impact des Features Manuelles
#
# Test des 5 stratégies complètes

# %%
print("Test 3: Impact des features manuelles\n")

# Utiliser la fonction run_strategy_comparison
results_strategies = run_strategy_comparison(
    X_train, X_val, y_train, y_val,
    text_columns=['title_clean', 'desc_clean'],
    feature_columns=feature_columns,
    models=['logreg'],  # Seul LogReg pour contrôle
    max_features=10000,
    ngram_range=(1, 2),
    verbose=True
)

print("\n✓ Comparaison terminée")
# Out:
# Test 3: Impact des features manuelles
#
#
# ================================================================================
# COMPARAISON COMPLÈTE DES STRATÉGIES DE VECTORISATION
# ================================================================================
# Modèles à tester: ['logreg']
# Max features: 10000
# N-gram range: (1, 2)
# ================================================================================
#
#
# 📊 STRATÉGIE 1: Indicateurs seuls
# --------------------------------------------------------------------------------
#   Modèle: LOGREG
#     F1: 0.2922, Acc: 0.3398
#
#
# 📊 STRATÉGIE 2: CountVectorizer seul
# --------------------------------------------------------------------------------
#   Modèle: LOGREG
#
# ================================================================================
# Expérience: COUNT + LOGREG
#   Strategy: split
#   Max features: 10000
#   N-gram range: (1, 2)
#   Features manuelles: Non
# ================================================================================
#
#     F1: 0.8187, Acc: 0.8160
#
#
# 📊 STRATÉGIE 3: TF-IDF seul
# --------------------------------------------------------------------------------
#   Modèle: LOGREG
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 10000
#   N-gram range: (1, 2)
#   Features manuelles: Non
# ================================================================================
#
#     F1: 0.8250, Acc: 0.8235
#
#
# 📊 STRATÉGIE 4: Indicateurs + CountVectorizer
# --------------------------------------------------------------------------------
#   Modèle: LOGREG
#
# ================================================================================
# Expérience: COUNT + LOGREG
#   Strategy: split
#   Max features: 10000
#   N-gram range: (1, 2)
#   Features manuelles: Oui
# ================================================================================
#
#     F1: 0.8232, Acc: 0.8212
#
#
# 📊 STRATÉGIE 5: Indicateurs + TF-IDF
# --------------------------------------------------------------------------------
#   Modèle: LOGREG
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 10000
#   N-gram range: (1, 2)
#   Features manuelles: Oui
# ================================================================================
#
#     F1: 0.8293, Acc: 0.8281
#
#
# ================================================================================
# RÉSUMÉ DES RÉSULTATS (triés par F1-Score)
# ================================================================================
#                      strategy vectorizer  model  use_features  f1_score  accuracy  train_time  predict_time
#          Indicateurs + TF-IDF      tfidf logreg          True  0.829302  0.828073   38.599605      0.569539
#                   TF-IDF seul      tfidf logreg         False  0.825009  0.823520   19.774422      0.553806
# Indicateurs + CountVectorizer      count logreg          True  0.823153  0.821165   35.786741      0.551562
#          CountVectorizer seul      count logreg         False  0.818727  0.815984   29.274926      0.544450
#             Indicateurs seuls       None logreg          True  0.292153  0.339849    3.930470      0.003118
# ================================================================================
#
# 🏆 MEILLEURE STRATÉGIE: Indicateurs + TF-IDF
#    Modèle: LOGREG
#    F1-Score: 0.8293
#    Accuracy: 0.8281
# ================================================================================
#
#
# ✓ Comparaison terminée

# %% [markdown]
# ## 8. Expérience 4: Grid Search Hyperparamètres
#
# Optimisation de max_features et ngram_range

# %%
# Déterminer le meilleur vectorizer depuis Exp 3
best_from_exp3 = results_strategies.iloc[0]
best_vectorizer_type = best_from_exp3['vectorizer']
use_features = best_from_exp3['use_features']

# Extraire le meilleur title_weight depuis Exp 2b
best_title_weight = results_weighting.iloc[0]['title_weight']

print(f"Grid search avec:")
print(f"  Vectorizer: {best_vectorizer_type}")
print(f"  Features: {use_features}")
print(f"  Title weight: {best_title_weight}x (optimal de Exp 2b)")
print()

# Grid search avec title_weight optimal
grid_results = run_hyperparameter_grid(
    X_train, X_val, y_train, y_val,
    vectorizer_type=best_vectorizer_type if best_vectorizer_type != 'None' else 'tfidf',
    max_features_list=[5000, 10000, 15000, 20000],
    ngram_range_list=[(1, 1), (1, 2), (1, 3)],
    model_name='logreg',
    text_columns=['title_clean', 'desc_clean'],
    feature_columns=feature_columns if use_features else None,
    title_weight=best_title_weight,
    verbose=True
)
# Out:
# Grid search avec:
#   Vectorizer: tfidf
#   Features: True
#   Title weight: 1.5x (optimal de Exp 2b)
#
#
# ================================================================================
# GRID SEARCH: TFIDF Hyperparameters
# ================================================================================
# Total expériences: 12
#   max_features: [5000, 10000, 15000, 20000]
#   ngram_range: [(1, 1), (1, 2), (1, 3)]
#   title_weight: 1.5
#   model: logreg
# ================================================================================
#
# [1/12] max_features=5000, ngram_range=(1, 1)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 5000
#   N-gram range: (1, 1)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8241, Acc: 0.8233
#
# [2/12] max_features=5000, ngram_range=(1, 2)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 5000
#   N-gram range: (1, 2)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8206, Acc: 0.8197
#
# [3/12] max_features=5000, ngram_range=(1, 3)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 5000
#   N-gram range: (1, 3)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8206, Acc: 0.8195
#
# [4/12] max_features=10000, ngram_range=(1, 1)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 10000
#   N-gram range: (1, 1)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8361, Acc: 0.8356
#
# [5/12] max_features=10000, ngram_range=(1, 2)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 10000
#   N-gram range: (1, 2)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8352, Acc: 0.8344
#
# [6/12] max_features=10000, ngram_range=(1, 3)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 10000
#   N-gram range: (1, 3)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8341, Acc: 0.8332
#
# [7/12] max_features=15000, ngram_range=(1, 1)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 15000
#   N-gram range: (1, 1)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8398, Acc: 0.8392
#
# [8/12] max_features=15000, ngram_range=(1, 2)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 15000
#   N-gram range: (1, 2)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8406, Acc: 0.8400
#
# [9/12] max_features=15000, ngram_range=(1, 3)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 15000
#   N-gram range: (1, 3)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8366, Acc: 0.8360
#
# [10/12] max_features=20000, ngram_range=(1, 1)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 20000
#   N-gram range: (1, 1)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8409, Acc: 0.8401
#
# [11/12] max_features=20000, ngram_range=(1, 2)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 20000
#   N-gram range: (1, 2)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8420, Acc: 0.8413
#
# [12/12] max_features=20000, ngram_range=(1, 3)
#
# ================================================================================
# Expérience: TFIDF + LOGREG
#   Strategy: split
#   Max features: 20000
#   N-gram range: (1, 3)
#   Features manuelles: Oui
# ================================================================================
#
#   → F1: 0.8407, Acc: 0.8400
#
#
# ================================================================================
# MEILLEURE CONFIGURATION:
# ================================================================================
#   Max features: 20000
#   N-gram range: (1, 2)
#   F1-Score: 0.8420
#   Accuracy: 0.8413
# ================================================================================

# %% [markdown]
# ## 9. Analyse & Visualisation

# %%
# Analyser grid results
analyze_experiment_results(
    grid_results,
    baseline_f1=baseline_f1,
    show_plot=True
)
# Out:
# ================================================================================
# ANALYSE DES RÉSULTATS
# ================================================================================
#
# Nombre d'expériences: 12
# F1-Score moyen: 0.8343
# F1-Score médian: 0.8364
# F1-Score min: 0.8206
# F1-Score max: 0.8420
# Écart-type: 0.0080
#
# Baseline F1: 0.7925
# Expériences supérieures à baseline: 12 / 12
# Meilleure amélioration: +6.25%
#
# --------------------------------------------------------------------------------
# PERFORMANCE PAR MODÈLE:
# --------------------------------------------------------------------------------
#             mean       max  count
# model
# logreg  0.834284  0.842012     12
# ================================================================================

# %% [markdown]
# ## 10. Configuration Optimale
#
# Identification et sauvegarde de la meilleure configuration

# %%
# Meilleure configuration
best = grid_results.iloc[0]

print("="*80)
print("🏆 CONFIGURATION OPTIMALE")
print("="*80)
print(f"Vectorizer: {best['vectorizer'].upper()}")
print(f"Max features: {best['max_features']}")
print(f"N-gram range: {best['ngram_range']}")
print(f"Features manuelles: {'Oui' if best['use_features'] else 'Non'}")
print(f"\nPerformance:")
print(f"  F1-Score: {best['f1_score']:.4f}")
print(f"  Accuracy: {best['accuracy']:.4f}")
improvement_vs_baseline = (best['f1_score'] - baseline_f1) / baseline_f1 * 100
print(f"  Amélioration vs baseline: {improvement_vs_baseline:+.2f}%")
print("="*80)
# Out:
# ================================================================================
# 🏆 CONFIGURATION OPTIMALE
# ================================================================================
# Vectorizer: TFIDF
# Max features: 20000
# N-gram range: (1, 2)
# Features manuelles: Oui
#
# Performance:
#   F1-Score: 0.8420
#   Accuracy: 0.8413
#   Amélioration vs baseline: +6.25%
# ================================================================================

# %% [markdown]
# ## 11. Export Configuration
#
# Sauvegarder pour Notebook 03

# %%
# Construire le dictionnaire de configuration
import ast

ngram_tuple = ast.literal_eval(best['ngram_range']) if isinstance(best['ngram_range'], str) else best['ngram_range']

BEST_CONFIG = {
    'vectorizer_type': best['vectorizer'],
    'strategy': 'split',
    'text_columns': ['title_clean', 'desc_clean'],
    'feature_columns': feature_columns if best['use_features'] else None,
    'max_features_title': int(best['max_features']),
    'max_features_desc': int(best['max_features']),
    'ngram_range': ngram_tuple,
    'title_weight': float(best.get('title_weight', 1.0)),
    'min_df': 2,
    'max_df': 0.95
}

# Sauvegarder
save_vectorization_config(
    BEST_CONFIG,
    'results/configs/best_vectorization_config.json',
    metadata={
        'f1_score': float(best['f1_score']),
        'accuracy': float(best['accuracy']),
        'train_time': float(best['train_time']),
        'notebook': '02_Vectorization_Strategies.ipynb',
        'baseline_f1': baseline_f1,
        'improvement_pct': float(improvement_vs_baseline),
        'title_weight': float(best.get('title_weight', 1.0))
    }
)

print("\n✓ Configuration exportée vers: results/configs/best_vectorization_config.json")
print("✓ Prête pour Notebook 03 (Model Selection)")
# Out:
# ✓ Configuration sauvegardée: results/configs/best_vectorization_config.json
#
# ✓ Configuration exportée vers: results/configs/best_vectorization_config.json
# ✓ Prête pour Notebook 03 (Model Selection)

# %% [markdown]
# ## 12. Conclusions & Rapport Final
#
# **Génération automatique** du rapport complet avec:
# - ✅ Tracking global de tous les scores
# - ✅ Vérification de l'optimalité de la configuration
# - ✅ Résumé détaillé des 5 découvertes principales
# - ✅ Performance finale et prochaines étapes
#
# Le rapport est affiché ci-dessous et sauvegardé dans `results/vectorization_report.txt`.

# %%
# ============================================================================
# GÉNÉRATION DU RAPPORT COMPLET
# ============================================================================

report = generate_vectorization_report(
    df_vec=df_vec,
    results_weighting=results_weighting,
    results_strategies=results_strategies,
    grid_results=grid_results,
    result_tfidf=result_tfidf,
    result_merged=result_merged,
    baseline_f1=baseline_f1,
    save_report=True,
    report_path='results/vectorization_report.txt',
    verbose=True
)

# Résumé rapide
print("\n" + "="*80)
print("RÉSUMÉ RAPIDE")
print("="*80)
print(f"✓ Configuration optimale: {'✅ OUI' if report['is_optimal'] else '⚠️ NON'}")
print(f"✓ Meilleur F1 score: {report['best_score']:.4f}")
print(f"✓ Baseline F1: {report['baseline_score']:.4f}")
print(f"✓ Amélioration totale: +{report['total_improvement_pct']:.2f}%")
print(f"\n✓ Rapport sauvegardé: results/vectorization_report.txt")
print(f"✓ Tracking sauvegardé: results/all_scores_tracking.csv")
print("="*80)
# Out:
# ✓ Rapport sauvegardé: results/vectorization_report.txt
#
# ================================================================================
# 📊 RAPPORT DE VECTORISATION - PHASE 2
# ================================================================================
# Généré le: 2025-12-08 16:02:56
# Total expériences: 24
#
# ================================================================================
# RÉSUMÉ DES DÉCOUVERTES
# ================================================================================
#
# 1️⃣  Count vs TF-IDF
#    → TF-IDF (F1=0.8250) surpasse Count (F1=0.8187)
#    → Amélioration: +0.77%
#
# 2️⃣  Split vs Merged
#    → Split (F1=0.8250) surpasse Merged (F1=0.7950)
#    → Amélioration: +3.77%
#
# 3️⃣  Pondération du Titre
#    → Poids optimal: 1.5x
#    → F1 = 0.8310 (baseline 1.0x: 0.8250)
#    → Amélioration: +0.72%
#
# 4️⃣  Features Manuelles
#    → Sans features: F1 = 0.8250
#    → Avec features: F1 = 0.8293
#    → Amélioration: +0.52%
#
# 5️⃣  Hyperparamètres Optimaux
#    → Vectorizer: TFIDF
#    → Max features: 20,000
#    → N-gram range: (1, 2)
#    → Title weight: 1.5x
#    → Features manuelles: Oui
#    → F1 Final: 0.8420
#
# ================================================================================
# 🏆 PERFORMANCE FINALE
# ================================================================================
# Baseline (raw data, NB01):              F1 = 0.7925
# Meilleur score (configuration finale):  F1 = 0.8420
# Amélioration totale:                    +6.25%
#
# Statut: ✅ Configuration optimale validée
#
# ================================================================================
# 🔍 VÉRIFICATION
# ================================================================================
# Config exportée: results/configs/best_vectorization_config.json
# Tracking sauvegardé: results/all_scores_tracking.csv
# Score config finale: F1 = 0.8420
# Meilleur score global: F1 = 0.8420
#
# ================================================================================
# 📋 PROCHAINES ÉTAPES
# ================================================================================
# → Notebook 03: Sélection du meilleur modèle
# → Phase 3: Intégration des features images
# → Phase 4: Fusion multimodale
# ================================================================================
#
# ================================================================================
# RÉSUMÉ RAPIDE
# ================================================================================
# ✓ Configuration optimale: ✅ OUI
# ✓ Meilleur F1 score: 0.8420
# ✓ Baseline F1: 0.7925
# ✓ Amélioration totale: +6.25%
#
# ✓ Rapport sauvegardé: results/vectorization_report.txt
# ✓ Tracking sauvegardé: results/all_scores_tracking.csv
# ================================================================================
